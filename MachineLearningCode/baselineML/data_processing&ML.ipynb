# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# --> 566         parts = [self.recv(flags, copy=copy, track=track)]
#     567         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     249       with _output.use_tags('dfs-auth-dance'):
#     250         with open(fifo, 'w') as fifo_file:
# --> 251           fifo_file.write(get_code(auth_prompt) + '\n')
#     252       wrote_to_fifo = True
#     253     elif case == 5:
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# Angry Data Check

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
sns.set_style('white')
import matplotlib.pyplot as plt
import glob
# get data file names
path =r"/content/drive/MyDrive/testData/5dec/processed_angry_820"
image_count = 600
filenames = glob.glob(path + "/*.csv")
#print(filenames)
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))
print(len(dfs))
# Concatenate all data into one DataFrame
df_angry = pd.concat(dfs, ignore_index=True)
# Remove empty spaces in column names.
df_angry.columns = [col.replace(" ", "") for col in df_angry.columns]
# Print few values of data.
#print(f"Max number of frames {df_angry.frame.max()}", f"\nTotal shape of dataframe {df_angry.shape}")
print(f'shape: {df_angry.shape}')
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
print ('Count of deteced faces with confidence larger than 0.8: %s' % (df_angry[df_angry["confidence"] > 0.8]['confidence'].count()))
print (f'Overall Accuracy of {image_count} images: %.3f%%' % ((df_angry[df_angry["confidence"] > 0.8]['confidence'].count() / image_count * 100)))
# Out:
# 500
# shape: (540, 711)
# Count of deteced faces with confidence larger than 0.8: 430
# Overall Accuracy of 600 images: 71.667%

# %% [markdown]
# Happy Data Check

# %%
# get data file names
path =r"/content/drive/MyDrive/testData/5dec/processed_happy_820"
filenames = glob.glob(path + "/*.csv")
print(len(filenames))
image_count = 600
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))
print(len(dfs))
# Concatenate all data into one DataFrame
df_happy = pd.concat(dfs, ignore_index=True)
# Remove empty spaces in column names.
df_happy.columns = [col.replace(" ", "") for col in df_happy.columns]
# Print few values of data.
#print(f"Max number of frames {df_happy.frame.max()}", f"\nTotal shape of dataframe {df_happy.shape}")
print(f'shape: {df_happy.shape}')
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
print ('Count of deteced faces with confidence larger than 0.8: %s' % (df_happy[df_happy["confidence"] > 0.8]['confidence'].count()))
print (f'Overall Accuracy of {image_count} images: %.3f%%' % ((df_happy[df_happy["confidence"] > 0.8]['confidence'].count() / image_count * 100)))
# Out:
# 497
# 497
# shape: (543, 711)
# Count of deteced faces with confidence larger than 0.8: 459
# Overall Accuracy of 600 images: 76.500%

# %% [markdown]
# Crying Data Check

# %%
# get data file names
path =r"/content/drive/MyDrive/testData/5dec/processed_crying_820"
image_count = 600
filenames = glob.glob(path + "/*.csv")
#print(filenames)
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))
print(len(dfs))
# Concatenate all data into one DataFrame
df_crying = pd.concat(dfs, ignore_index=True)
# Remove empty spaces in column names.
df_crying.columns = [col.replace(" ", "") for col in df_crying.columns]
# Print few values of data.
#print(f"Max number of frames {df_crying.frame.max()}", f"\nTotal shape of dataframe {df_crying.shape}")
print(f'shape: {df_crying.shape}')
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
print ('Count of deteced faces with confidence larger than 0.8: %s' % (df_crying[df_crying["confidence"] > 0.8]['confidence'].count()))
print (f'Overall Accuracy of {image_count} images: %.3f%%' % ((df_crying[df_crying["confidence"] > 0.8]['confidence'].count() / image_count * 100)))
# Out:
# 487
# shape: (528, 711)
# Count of deteced faces with confidence larger than 0.8: 419
# Overall Accuracy of 600 images: 69.833%

# %% [markdown]
# Clean and Construct Data

# %%
df_arr = [df_angry, df_happy, df_crying]
clean_df_arr = []
for i, df in enumerate(df_arr):
  #keep face detection that has more than 0.8 confidence
  df = df[df['confidence'] > 0.8]
  #filter columns (get AU columns only)
  df = df.filter(regex=('^AU.*r$'))
  #add class index 0 - angry, 1 - happy, 2 - crying
  df["label"] = str(i)
  clean_df_arr.append(df)
print(f'angry data count: {len(clean_df_arr[0])}, shape: {clean_df_arr[0].shape}\nhappy data count: {len(clean_df_arr[1])}, shape: {clean_df_arr[1].shape} \ncrying data count: {len(clean_df_arr[2])}, shape: {clean_df_arr[2].shape}')
#concat the list of arr to one df for ML
#clean_data = pd.concat(clean_df_arr, ignore_index=True)
#print(f'total data shape:{clean_data.shape}')
#cleaned_data
# Out:
# angry data count: 430, shape: (430, 18)
# happy data count: 459, shape: (459, 18)
# crying data count: 419, shape: (419, 18)

# %% [markdown]
# ML training

# %%
import tensorflow as tf
from numpy import random
from keras.models import Sequential
from keras.layers import Dense
import keras.backend as K
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot
from keras.models import model_from_json

num_features = 17
train_df_arr = []
test_df_arr = []
for df in clean_df_arr:
  train, test = train_test_split(df, test_size=0.2)
  train_df_arr.append(train)
  test_df_arr.append(test)
#concat data from different expression
train_data = pd.concat(train_df_arr, ignore_index=True)
test_data = pd.concat(test_df_arr, ignore_index=True)
#shuffle data
train_data = train_data.sample(frac=1)
test_data = test_data.sample(frac=1)
#transform label column to columns by class with boolean value: angry('0': 1, '1', 0, '2', 1)
y_train = train_data['label'].str.get_dummies()
y_test = test_data['label'].str.get_dummies()
print(f'train data shape: {train_data.shape}')
print(f'test data shape: {test_data.shape}')
# neural network
model = Sequential()
#input layer, input_shape(<num features>)
model.add(Dense(64, activation='relu', input_shape=(num_features,)))
#hidden layer
model.add(Dense(32, activation='relu'))
#output layer
model.add(Dense(3, activation='sigmoid'))
# opt = SGD(lr=0.0202, momentum=0.9)
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
# model check point to save model that has the best accuracy
mc = ModelCheckpoint('./drive/MyDrive/best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
#train
history = model.fit(train_data.drop(['label'], axis = 1), y_train, validation_split=0.2, epochs=1000, batch_size=256, verbose=0, callbacks=[es, mc])
#test
#y_predict = model.predict(test_data.drop(['label'], axis = 1))
saved_model = load_model('./drive/MyDrive/best_model.h5')
result_stat = saved_model.evaluate(test_data.drop(['label'], axis = 1), y_test)
print(f'test loss: {result_stat[0]}\ntest accuracy: {result_stat[1]}')
# plot training history
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.show()
# serialize model to JSON
model_json = model.to_json()
with open("./drive/MyDrive/model.json", "w") as json_file:
    json_file.write(model_json)
# Out:
# train data shape: (1046, 18)
# test data shape: (262, 18)
#
# Epoch 00001: val_accuracy improved from -inf to 0.31905, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00002: val_accuracy improved from 0.31905 to 0.51905, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00003: val_accuracy improved from 0.51905 to 0.74286, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00004: val_accuracy improved from 0.74286 to 0.75714, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00005: val_accuracy improved from 0.75714 to 0.77143, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00006: val_accuracy improved from 0.77143 to 0.79524, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00007: val_accuracy improved from 0.79524 to 0.80476, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00008: val_accuracy improved from 0.80476 to 0.81905, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00009: val_accuracy improved from 0.81905 to 0.83333, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00010: val_accuracy improved from 0.83333 to 0.84286, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00011: val_accuracy did not improve from 0.84286
#
# Epoch 00012: val_accuracy did not improve from 0.84286
#
# Epoch 00013: val_accuracy did not improve from 0.84286
#
# Epoch 00014: val_accuracy did not improve from 0.84286
#
# Epoch 00015: val_accuracy did not improve from 0.84286
#
# Epoch 00016: val_accuracy did not improve from 0.84286
#
# Epoch 00017: val_accuracy did not improve from 0.84286
#
# Epoch 00018: val_accuracy did not improve from 0.84286
#
# Epoch 00019: val_accuracy did not improve from 0.84286
#
# Epoch 00020: val_accuracy improved from 0.84286 to 0.84762, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00021: val_accuracy did not improve from 0.84762
#
# Epoch 00022: val_accuracy improved from 0.84762 to 0.86190, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00023: val_accuracy did not improve from 0.86190
#
# Epoch 00024: val_accuracy did not improve from 0.86190
#
# Epoch 00025: val_accuracy did not improve from 0.86190
#
# Epoch 00026: val_accuracy did not improve from 0.86190
#
# Epoch 00027: val_accuracy improved from 0.86190 to 0.86667, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00028: val_accuracy improved from 0.86667 to 0.89048, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00029: val_accuracy did not improve from 0.89048
#
# Epoch 00030: val_accuracy did not improve from 0.89048
#
# Epoch 00031: val_accuracy did not improve from 0.89048
#
# Epoch 00032: val_accuracy did not improve from 0.89048
#
# Epoch 00033: val_accuracy did not improve from 0.89048
#
# Epoch 00034: val_accuracy did not improve from 0.89048
#
# Epoch 00035: val_accuracy did not improve from 0.89048
#
# Epoch 00036: val_accuracy improved from 0.89048 to 0.90000, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00037: val_accuracy did not improve from 0.90000
#
# Epoch 00038: val_accuracy did not improve from 0.90000
#
# Epoch 00039: val_accuracy did not improve from 0.90000
#
# Epoch 00040: val_accuracy did not improve from 0.90000
#
# Epoch 00041: val_accuracy improved from 0.90000 to 0.90476, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00042: val_accuracy did not improve from 0.90476
#
# Epoch 00043: val_accuracy improved from 0.90476 to 0.91429, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00044: val_accuracy did not improve from 0.91429
#
# Epoch 00045: val_accuracy did not improve from 0.91429
#
# Epoch 00046: val_accuracy did not improve from 0.91429
#
# Epoch 00047: val_accuracy did not improve from 0.91429
#
# Epoch 00048: val_accuracy improved from 0.91429 to 0.91905, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00049: val_accuracy did not improve from 0.91905
#
# Epoch 00050: val_accuracy did not improve from 0.91905
#
# Epoch 00051: val_accuracy did not improve from 0.91905
#
# Epoch 00052: val_accuracy did not improve from 0.91905
#
# Epoch 00053: val_accuracy did not improve from 0.91905
#
# Epoch 00054: val_accuracy did not improve from 0.91905
#
# Epoch 00055: val_accuracy improved from 0.91905 to 0.92381, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00056: val_accuracy did not improve from 0.92381
#
# Epoch 00057: val_accuracy did not improve from 0.92381
#
# Epoch 00058: val_accuracy did not improve from 0.92381
#
# Epoch 00059: val_accuracy did not improve from 0.92381
#
# Epoch 00060: val_accuracy did not improve from 0.92381
#
# Epoch 00061: val_accuracy did not improve from 0.92381
#
# Epoch 00062: val_accuracy improved from 0.92381 to 0.92857, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00063: val_accuracy did not improve from 0.92857
#
# Epoch 00064: val_accuracy did not improve from 0.92857
#
# Epoch 00065: val_accuracy did not improve from 0.92857
#
# Epoch 00066: val_accuracy did not improve from 0.92857
#
# Epoch 00067: val_accuracy did not improve from 0.92857
#
# Epoch 00068: val_accuracy did not improve from 0.92857
#
# Epoch 00069: val_accuracy did not improve from 0.92857
#
# Epoch 00070: val_accuracy did not improve from 0.92857
#
# Epoch 00071: val_accuracy did not improve from 0.92857
#
# Epoch 00072: val_accuracy did not improve from 0.92857
#
# Epoch 00073: val_accuracy did not improve from 0.92857
#
# Epoch 00074: val_accuracy did not improve from 0.92857
#
# Epoch 00075: val_accuracy did not improve from 0.92857
#
# Epoch 00076: val_accuracy improved from 0.92857 to 0.93333, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00077: val_accuracy did not improve from 0.93333
#
# Epoch 00078: val_accuracy did not improve from 0.93333
#
# Epoch 00079: val_accuracy did not improve from 0.93333
#
# Epoch 00080: val_accuracy did not improve from 0.93333
#
# Epoch 00081: val_accuracy did not improve from 0.93333
#
# Epoch 00082: val_accuracy improved from 0.93333 to 0.93810, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00083: val_accuracy did not improve from 0.93810
#
# Epoch 00084: val_accuracy did not improve from 0.93810
#
# Epoch 00085: val_accuracy did not improve from 0.93810
#
# Epoch 00086: val_accuracy did not improve from 0.93810
#
# Epoch 00087: val_accuracy did not improve from 0.93810
#
# Epoch 00088: val_accuracy did not improve from 0.93810
#
# Epoch 00089: val_accuracy did not improve from 0.93810
#
# Epoch 00090: val_accuracy did not improve from 0.93810
#
# Epoch 00091: val_accuracy did not improve from 0.93810
#
# Epoch 00092: val_accuracy did not improve from 0.93810
#
# Epoch 00093: val_accuracy did not improve from 0.93810
#
# Epoch 00094: val_accuracy did not improve from 0.93810
#
# Epoch 00095: val_accuracy did not improve from 0.93810
#
# Epoch 00096: val_accuracy improved from 0.93810 to 0.94286, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00097: val_accuracy did not improve from 0.94286
#
# Epoch 00098: val_accuracy did not improve from 0.94286
#
# Epoch 00099: val_accuracy improved from 0.94286 to 0.94762, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00100: val_accuracy did not improve from 0.94762
#
# Epoch 00101: val_accuracy improved from 0.94762 to 0.95238, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00102: val_accuracy did not improve from 0.95238
#
# Epoch 00103: val_accuracy did not improve from 0.95238
#
# Epoch 00104: val_accuracy did not improve from 0.95238
#
# Epoch 00105: val_accuracy did not improve from 0.95238
#
# Epoch 00106: val_accuracy did not improve from 0.95238
#
# Epoch 00107: val_accuracy did not improve from 0.95238
#
# Epoch 00108: val_accuracy did not improve from 0.95238
#
# Epoch 00109: val_accuracy did not improve from 0.95238
#
# Epoch 00110: val_accuracy did not improve from 0.95238
#
# Epoch 00111: val_accuracy did not improve from 0.95238
#
# Epoch 00112: val_accuracy improved from 0.95238 to 0.95714, saving model to ./drive/MyDrive/best_model.h5
#
# Epoch 00113: val_accuracy did not improve from 0.95714
#
# Epoch 00114: val_accuracy did not improve from 0.95714
#
# Epoch 00115: val_accuracy did not improve from 0.95714
#
# Epoch 00116: val_accuracy did not improve from 0.95714
#
# Epoch 00117: val_accuracy did not improve from 0.95714
#
# Epoch 00118: val_accuracy did not improve from 0.95714
#
# Epoch 00119: val_accuracy did not improve from 0.95714
#
# Epoch 00120: val_accuracy did not improve from 0.95714
#
# Epoch 00121: val_accuracy did not improve from 0.95714
#
# Epoch 00122: val_accuracy did not improve from 0.95714
#
# Epoch 00123: val_accuracy did not improve from 0.95714
#
# Epoch 00124: val_accuracy did not improve from 0.95714
#
# Epoch 00125: val_accuracy did not improve from 0.95714
#
# Epoch 00126: val_accuracy did not improve from 0.95714
#
# Epoch 00127: val_accuracy did not improve from 0.95714
#
# Epoch 00128: val_accuracy did not improve from 0.95714
#
# Epoch 00129: val_accuracy did not improve from 0.95714
#
# Epoch 00130: val_accuracy did not improve from 0.95714
#
# Epoch 00131: val_accuracy did not improve from 0.95714
#
# Epoch 00132: val_accuracy did not improve from 0.95714
#
# Epoch 00133: val_accuracy did not improve from 0.95714
#
# Epoch 00134: val_accuracy did not improve from 0.95714
#
# Epoch 00135: val_accuracy did not improve from 0.95714
#
# Epoch 00136: val_accuracy did not improve from 0.95714
#
# Epoch 00137: val_accuracy did not improve from 0.95714
#
# Epoch 00138: val_accuracy did not improve from 0.95714
#
# Epoch 00139: val_accuracy did not improve from 0.95714
#
# Epoch 00140: val_accuracy did not improve from 0.95714
#
# Epoch 00141: val_accuracy did not improve from 0.95714
#
# Epoch 00142: val_accuracy did not improve from 0.95714
#
# Epoch 00143: val_accuracy did not improve from 0.95714
#
# Epoch 00144: val_accuracy did not improve from 0.95714
#
# Epoch 00145: val_accuracy did not improve from 0.95714
#
# Epoch 00146: val_accuracy did not improve from 0.95714
#
# Epoch 00147: val_accuracy did not improve from 0.95714
#
# Epoch 00148: val_accuracy did not improve from 0.95714
#
# Epoch 00149: val_accuracy did not improve from 0.95714
#
# Epoch 00150: val_accuracy did not improve from 0.95714
#
# Epoch 00151: val_accuracy did not improve from 0.95714
#
# Epoch 00152: val_accuracy did not improve from 0.95714
#
# Epoch 00153: val_accuracy did not improve from 0.95714
#
# Epoch 00154: val_accuracy did not improve from 0.95714
#
# Epoch 00155: val_accuracy did not improve from 0.95714
#
# Epoch 00156: val_accuracy did not improve from 0.95714
#
# Epoch 00157: val_accuracy did not improve from 0.95714
#
# Epoch 00158: val_accuracy did not improve from 0.95714
#
# Epoch 00159: val_accuracy did not improve from 0.95714
#
# Epoch 00160: val_accuracy did not improve from 0.95714
#
# Epoch 00161: val_accuracy did not improve from 0.95714
#
# Epoch 00162: val_accuracy did not improve from 0.95714
#
# Epoch 00163: val_accuracy did not improve from 0.95714
#
# Epoch 00164: val_accuracy did not improve from 0.95714
#
# Epoch 00165: val_accuracy did not improve from 0.95714
#
# Epoch 00166: val_accuracy did not improve from 0.95714
#
# Epoch 00167: val_accuracy did not improve from 0.95714
#
# Epoch 00168: val_accuracy did not improve from 0.95714
#
# Epoch 00169: val_accuracy did not improve from 0.95714
#
# Epoch 00170: val_accuracy did not improve from 0.95714
#
# Epoch 00171: val_accuracy did not improve from 0.95714
#
# Epoch 00172: val_accuracy did not improve from 0.95714
#
# Epoch 00173: val_accuracy did not improve from 0.95714
#
# Epoch 00174: val_accuracy did not improve from 0.95714
#
# Epoch 00175: val_accuracy did not improve from 0.95714
#
# Epoch 00176: val_accuracy did not improve from 0.95714
#
# Epoch 00177: val_accuracy did not improve from 0.95714
#
# Epoch 00178: val_accuracy did not improve from 0.95714
#
# Epoch 00179: val_accuracy did not improve from 0.95714
#
# Epoch 00180: val_accuracy did not improve from 0.95714
#
# Epoch 00181: val_accuracy did not improve from 0.95714
#
# Epoch 00182: val_accuracy did not improve from 0.95714
#
# Epoch 00183: val_accuracy did not improve from 0.95714
#
# Epoch 00184: val_accuracy did not improve from 0.95714
#
# Epoch 00185: val_accuracy did not improve from 0.95714
#
# Epoch 00186: val_accuracy did not improve from 0.95714
#
# Epoch 00187: val_accuracy did not improve from 0.95714
#
# Epoch 00188: val_accuracy did not improve from 0.95714
#
# Epoch 00189: val_accuracy did not improve from 0.95714
#
# Epoch 00190: val_accuracy did not improve from 0.95714
#
# Epoch 00191: val_accuracy did not improve from 0.95714
#
# Epoch 00192: val_accuracy did not improve from 0.95714
#
# Epoch 00193: val_accuracy did not improve from 0.95714
#
# Epoch 00194: val_accuracy did not improve from 0.95714
#
# Epoch 00195: val_accuracy did not improve from 0.95714
#
# Epoch 00196: val_accuracy did not improve from 0.95714
#
# Epoch 00197: val_accuracy did not improve from 0.95714
#
# Epoch 00198: val_accuracy did not improve from 0.95714
#
# Epoch 00199: val_accuracy did not improve from 0.95714
#
# Epoch 00200: val_accuracy did not improve from 0.95714
#
# Epoch 00201: val_accuracy did not improve from 0.95714
#
# Epoch 00202: val_accuracy did not improve from 0.95714
#
# Epoch 00203: val_accuracy did not improve from 0.95714
#
# Epoch 00204: val_accuracy did not improve from 0.95714
#
# Epoch 00205: val_accuracy did not improve from 0.95714
#
# Epoch 00206: val_accuracy did not improve from 0.95714
#
# Epoch 00207: val_accuracy did not improve from 0.95714
#
# Epoch 00208: val_accuracy did not improve from 0.95714
#
# Epoch 00209: val_accuracy did not improve from 0.95714
#
# Epoch 00210: val_accuracy did not improve from 0.95714
#
# Epoch 00211: val_accuracy did not improve from 0.95714
#
# Epoch 00212: val_accuracy did not improve from 0.95714
#
# Epoch 00213: val_accuracy did not improve from 0.95714
#
# Epoch 00214: val_accuracy did not improve from 0.95714
#
# Epoch 00215: val_accuracy did not improve from 0.95714
#
# Epoch 00216: val_accuracy did not improve from 0.95714
#
# Epoch 00217: val_accuracy did not improve from 0.95714
#
# Epoch 00218: val_accuracy did not improve from 0.95714
#
# Epoch 00219: val_accuracy did not improve from 0.95714
#
# Epoch 00220: val_accuracy did not improve from 0.95714
#
# Epoch 00221: val_accuracy did not improve from 0.95714
#
# Epoch 00222: val_accuracy did not improve from 0.95714
#
# Epoch 00223: val_accuracy did not improve from 0.95714
#
# Epoch 00224: val_accuracy did not improve from 0.95714
#
# Epoch 00225: val_accuracy did not improve from 0.95714
#
# Epoch 00226: val_accuracy did not improve from 0.95714
#
# Epoch 00227: val_accuracy did not improve from 0.95714
#
# Epoch 00228: val_accuracy did not improve from 0.95714
#
# Epoch 00229: val_accuracy did not improve from 0.95714
#
# Epoch 00230: val_accuracy did not improve from 0.95714
#
# Epoch 00231: val_accuracy did not improve from 0.95714
#
# Epoch 00232: val_accuracy did not improve from 0.95714
#
# Epoch 00233: val_accuracy did not improve from 0.95714
#
# Epoch 00234: val_accuracy did not improve from 0.95714
#
# Epoch 00235: val_accuracy did not improve from 0.95714
#
# Epoch 00236: val_accuracy did not improve from 0.95714
#
# Epoch 00237: val_accuracy did not improve from 0.95714
#
# Epoch 00238: val_accuracy did not improve from 0.95714
#
# Epoch 00239: val_accuracy did not improve from 0.95714
#
# Epoch 00240: val_accuracy did not improve from 0.95714
#
# Epoch 00241: val_accuracy did not improve from 0.95714
#
# Epoch 00242: val_accuracy did not improve from 0.95714
#
# Epoch 00243: val_accuracy did not improve from 0.95714
#
# Epoch 00244: val_accuracy did not improve from 0.95714
#
# Epoch 00245: val_accuracy did not improve from 0.95714
#
# Epoch 00246: val_accuracy did not improve from 0.95714
# Epoch 00246: early stopping
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1046 - accuracy: 0.9389
# test loss: 0.10464153438806534
# test accuracy: 0.9389312863349915

# %% [markdown]
# Test on real faces data

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
sns.set_style('white')
import matplotlib.pyplot as plt
import glob
# get data file names
path =r"/content/drive/MyDrive/testData/5dec/processed_angry_real"
image_count = 6
filenames = glob.glob(path + "/*.csv")
#print(filenames)
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))
print(len(dfs))
# Concatenate all data into one DataFrame
df_angry_real = pd.concat(dfs, ignore_index=True)
# Remove empty spaces in column names.
df_angry_real.columns = [col.replace(" ", "") for col in df_angry_real.columns]
# Print few values of data.
#print(f"Max number of frames {df_angry_real.frame.max()}", f"\nTotal shape of dataframe {df_angry_real.shape}")
print(f'shape: {df_angry_real.shape}')
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
print ('Count of deteced faces with confidence larger than 0.8: %s' % (df_angry_real[df_angry_real["confidence"] > 0.8]['confidence'].count()))
print (f'Overall Accuracy of {image_count} images: %.3f%%' % ((df_angry_real[df_angry_real["confidence"] > 0.8]['confidence'].count() / image_count * 100)))
# Out:
# 6
# shape: (6, 711)
# Count of deteced faces with confidence larger than 0.8: 6
# Overall Accuracy of 6 images: 100.000%

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
sns.set_style('white')
import matplotlib.pyplot as plt
import glob
# get data file names
path =r"/content/drive/MyDrive/testData/5dec/processed_happy_real"
image_count = 6
filenames = glob.glob(path + "/*.csv")
#print(filenames)
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))
print(len(dfs))
# Concatenate all data into one DataFrame
df_happy_real = pd.concat(dfs, ignore_index=True)
# Remove empty spaces in column names.
df_happy_real.columns = [col.replace(" ", "") for col in df_happy_real.columns]
# Print few values of data.
#print(f"Max number of frames {df_happy_real.frame.max()}", f"\nTotal shape of dataframe {df_happy_real.shape}")
print(f'shape: {df_happy_real.shape}')
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
print ('Count of deteced faces with confidence larger than 0.8: %s' % (df_happy_real[df_happy_real["confidence"] > 0.8]['confidence'].count()))
print (f'Overall Accuracy of {image_count} images: %.3f%%' % ((df_happy_real[df_happy_real["confidence"] > 0.8]['confidence'].count() / image_count * 100)))
# Out:
# 6
# shape: (6, 711)
# Count of deteced faces with confidence larger than 0.8: 6
# Overall Accuracy of 6 images: 100.000%

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd, seaborn as sns
sns.set_style('white')
import matplotlib.pyplot as plt
import glob
# get data file names
path =r"/content/drive/MyDrive/testData/5dec/processed_crying_real"
image_count = 6
filenames = glob.glob(path + "/*.csv")
#print(filenames)
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))
print(len(dfs))
# Concatenate all data into one DataFrame
df_crying_real = pd.concat(dfs, ignore_index=True)
# Remove empty spaces in column names.
df_crying_real.columns = [col.replace(" ", "") for col in df_crying_real.columns]
# Print few values of data.
#print(f"Max number of frames {df_crying_real.frame.max()}", f"\nTotal shape of dataframe {df_crying_real.shape}")
print(f'shape: {df_crying_real.shape}')
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
print ('Count of deteced faces with confidence larger than 0.8: %s' % (df_crying_real[df_crying_real["confidence"] > 0.8]['confidence'].count()))
print (f'Overall Accuracy of {image_count} images: %.3f%%' % ((df_crying_real[df_crying_real["confidence"] > 0.8]['confidence'].count() / image_count * 100)))
# Out:
# 6
# shape: (6, 711)
# Count of deteced faces with confidence larger than 0.8: 6
# Overall Accuracy of 6 images: 100.000%

# %%
import numpy as np
df_real_arr = [df_angry_real, df_happy_real, df_crying_real]
#df_real_arr = [df_angry_real]
real_df_arr = []
for i, df in enumerate(df_real_arr):
  #keep face detection that has more than 0.8 confidence
  df = df[df['confidence'] > 0.8]
  #filter columns (get AU columns only)
  df = df.filter(regex=('^AU.*r$'))
  #add class index 0 - angry, 1 - happy, 2 - crying
  df["label"] = str(i)
  real_df_arr.append(df)
#print(f'angry data count: {len(real_df_arr[0])}, shape: {real_df_arr[0].shape}\nhappy data count: {len(real_df_arr[1])}, shape: {real_df_arr[1].shape} \ncrying data count: {len(real_df_arr[2])}, shape: {real_df_arr[2].shape}')

num_features = 17
df_arr_real = []
print(real_df_arr )

#concat data from different expression
test_data_real_2 = pd.concat(real_df_arr, ignore_index=True)
#shuffle data
test_data_real_2 = test_data_real_2.sample(frac=1)
#transform label column to columns by class with boolean value: angry('0': 1, '1', 0, '2', 0)
y_test_real = test_data_real_2['label'].str.get_dummies()
print(f'test data shape: {test_data_real_2.shape} {y_test_real.shape}')


json_file = open("./drive/MyDrive/model.json", 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("./drive/MyDrive/best_model.h5")
print("Loaded model from disk")
x = test_data_real_2.drop(['label'], axis = 1)
print(test_data_real_2)
ynew = loaded_model.predict_classes(x)
print(ynew)
# show the inputs and predicted outputs
#for i in range(len(x)):
	#print("X=%s, Predicted=%s" % (x[i], ynew[i]))
#prediction = np.round(loaded_model.predict(x))
#wrong_predictions = x[prediction != y_test_real]
# indices = [i for i,v in enumerate(pred) if pred[i]!=y_test_real[i]]
# subset_of_wrongly_predicted = [x[i] for i in indices]

# evaluate loaded model on test data
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
score = loaded_model.evaluate(test_data_real_2.drop(['label'], axis = 1), y_test_real, verbose=0)
#print('test loss: %.4f\ntest accuracy: %.2f%%' % (result_stat[0], result_stat[1]*100))
# plot training history
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.suptitle('Epoches vs Loss')
pyplot.ylabel('loss')
pyplot.xlabel('# of epoches')
pyplot.show()
#print("%s on real human face: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))

data = {'Loss': [result_stat[0], score[0]],
        'Accuracy(%)': [result_stat[1]*100, score[1]*100]
        }

df = pd.DataFrame(data, columns = ['Loss', 'Accuracy(%)'] ,index = ['Synthetic Human Testset', 'Real Human Testset'])
print(df)
# Out:
# [   AU01_r  AU02_r  AU04_r  AU05_r  AU06_r  ...  AU23_r  AU25_r  AU26_r  AU45_r  label
# 0    1.16    0.41    3.03    1.14    2.96  ...     0.0    4.55    0.97    0.00      0
# 1    0.00    0.00    1.21    0.25    2.11  ...     0.0    3.20    0.61    0.00      0
# 2    0.00    0.00    2.17    0.54    1.00  ...     1.0    0.00    0.18    0.00      0
# 3    0.00    0.00    1.19    0.44    1.10  ...     0.0    0.00    0.00    0.17      0
# 4    0.00    0.00    1.02    0.00    2.28  ...     0.0    2.96    0.00    0.00      0
# 5    2.35    1.57    0.26    2.33    1.22  ...     0.0    1.12    0.00    0.00      0
#
# [6 rows x 18 columns],    AU01_r  AU02_r  AU04_r  AU05_r  AU06_r  ...  AU23_r  AU25_r  AU26_r  AU45_r  label
# 0    1.16    0.81    0.00    1.02    2.42  ...    0.00    2.70    0.24     0.0      1
# 1    0.00    0.00    0.60    0.00    2.72  ...    0.26    2.45    0.22     0.0      1
# 2    0.00    0.00    0.00    0.00    0.86  ...    0.00    1.11    0.00     0.0      1
# 3    0.19    0.05    0.00    0.00    1.89  ...    0.07    2.98    0.27     0.0      1
# 4    0.20    0.11    0.16    1.01    2.35  ...    0.00    3.28    1.18     0.0      1
# 5    0.00    0.00    0.00    0.00    2.54  ...    0.00    2.30    0.46     0.0      1
#
# [6 rows x 18 columns],    AU01_r  AU02_r  AU04_r  AU05_r  AU06_r  ...  AU23_r  AU25_r  AU26_r  AU45_r  label
# 0    0.95    0.12    1.77    0.00    1.14  ...    0.00    0.00    0.30    0.00      2
# 1    0.00    0.00    0.19    0.00    0.24  ...    0.00    0.49    0.29    0.05      2
# 2    1.22    0.07    0.56    0.00    0.00  ...    0.00    0.23    0.00    0.00      2
# 3    0.18    0.00    0.00    0.64    0.11  ...    0.00    0.00    0.39    0.00      2
# 4    3.28    0.56    0.00    1.04    0.00  ...    0.00    0.51    0.00    0.00      2
# 5    0.07    0.00    2.69    0.00    0.78  ...    0.14    0.28    0.00    0.59      2
#
# [6 rows x 18 columns]]
# test data shape: (18, 18) (18, 3)
# Loaded model from disk
#     AU01_r  AU02_r  AU04_r  AU05_r  ...  AU25_r  AU26_r  AU45_r  label
# 4     0.00    0.00    1.02    0.00  ...    2.96    0.00    0.00      0
# 10    0.20    0.11    0.16    1.01  ...    3.28    1.18    0.00      1
# 15    0.18    0.00    0.00    0.64  ...    0.00    0.39    0.00      2
# 1     0.00    0.00    1.21    0.25  ...    3.20    0.61    0.00      0
# 3     0.00    0.00    1.19    0.44  ...    0.00    0.00    0.17      0
# 16    3.28    0.56    0.00    1.04  ...    0.51    0.00    0.00      2
# 14    1.22    0.07    0.56    0.00  ...    0.23    0.00    0.00      2
# 17    0.07    0.00    2.69    0.00  ...    0.28    0.00    0.59      2
# 13    0.00    0.00    0.19    0.00  ...    0.49    0.29    0.05      2
# 6     1.16    0.81    0.00    1.02  ...    2.70    0.24    0.00      1
# 12    0.95    0.12    1.77    0.00  ...    0.00    0.30    0.00      2
# 8     0.00    0.00    0.00    0.00  ...    1.11    0.00    0.00      1
# 7     0.00    0.00    0.60    0.00  ...    2.45    0.22    0.00      1
# 9     0.19    0.05    0.00    0.00  ...    2.98    0.27    0.00      1
# 0     1.16    0.41    3.03    1.14  ...    4.55    0.97    0.00      0
# 5     2.35    1.57    0.26    2.33  ...    1.12    0.00    0.00      0
# 2     0.00    0.00    2.17    0.54  ...    0.00    0.18    0.00      0
# 11    0.00    0.00    0.00    0.00  ...    2.30    0.46    0.00      1
#
# [18 rows x 18 columns]
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8f57c5e8c8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0 1 2 1 0 2 2 0 1 1 0 1 1 1 1 0 0 1]
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8f1b070d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#                              Loss  Accuracy(%)
# Synthetic Human Testset  0.104642    93.893129
# Real Human Testset       0.848520    72.222221

# %%
data = {'Percentage of detectable pictures(%)': [74.38, 70.21, 60.32],
        '300 images in Memory(mb)': [790.8, 195.5, 27.9]
        }

df = pd.DataFrame(data, columns = ['Percentage of detectable pictures(%)', '300 images in Memory(mb)'] ,index = ['1792x1267(original image size)', '820x580(our choice)', '256x181'])
print(df)
# Out:
#                                 Percentage of detectable pictures(%)  300 images in Memory(mb)
# 1792x1267(original image size)                                 74.38                     790.8
# 820x580(our choice)                                            70.21                     195.5
# 256x181                                                        60.32                      27.9
